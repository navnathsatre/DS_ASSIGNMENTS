# %% [markdown]
# Q 1) Perform sentimental analysis on the Elon-musk tweets (Exlon-musk.csv)

# %%
# Importing the data set
import pandas as pd
Elon_musk = pd.read_csv("D:\\DATA SCIENCE\\DATA SCIENCE ASSIGNMENTS\\Assignments\\Text Mining (NLP)\\Elon_musk.csv",encoding='latin-1')
Elon_musk
# Out:
#       Unnamed: 0                                               Text
# 0              1                             @kunalb11 Im an alien
# 1              2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2              3                @joerogan @Spotify Great interview!
# 3              4                    @gtera27 Doge is underestimated
# 4              5  @teslacn Congratulations Tesla China for amazi...
# ...          ...                                                ...
# 1994        1995  @flcnhvy True, it sounds so surreal, but the n...
# 1995        1996  @PPathole Make sure to read ur terms &amp; con...
# 1996        1997                @TeslaGong @PPathole Samwise Gamgee
# 1997        1998  @PPathole Altho Dumb and Dumber is <U+0001F525...
# 1998        1999                          Progress update August 28
#
# [1999 rows x 2 columns]

# %% [markdown]
# ## Preprocessing

# %%
Elon_musk = Elon_musk.drop(['Unnamed: 0'],axis=1)

# %%
Elon_musk
# Out:
#                                                    Text
# 0                                @kunalb11 Im an alien
# 1     @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2                   @joerogan @Spotify Great interview!
# 3                       @gtera27 Doge is underestimated
# 4     @teslacn Congratulations Tesla China for amazi...
# ...                                                 ...
# 1994  @flcnhvy True, it sounds so surreal, but the n...
# 1995  @PPathole Make sure to read ur terms &amp; con...
# 1996                @TeslaGong @PPathole Samwise Gamgee
# 1997  @PPathole Altho Dumb and Dumber is <U+0001F525...
# 1998                          Progress update August 28
#
# [1999 rows x 1 columns]

# %%
# remove both the leading and the trailing characters
df = [Text.strip() for Text in Elon_musk.Text]

# %%
df[0:20]
# Out:
# ['@kunalb11 I\x92m an alien',
#  '@ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?',
#  '@joerogan @Spotify Great interview!',
#  '@gtera27 Doge is underestimated',
#  '@teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!',
#  'Happy New Year of the Ox! https://t.co/9WFKMYu2oj',
#  'Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM',
#  '@OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)',
#  '@flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.',
#  'The most entertaining outcome is the most likely',
#  '@GiveDirectly Just sent some',
#  'Just agree to do Clubhouse with @kanyewest',
#  'https://t.co/3rWE9uHSTS',
#  '@geoffkeighley @UnrealEngine It\x92s getting real',
#  'Bought some Dogecoin for lil X, so he can be a toddler hodler',
#  '@JoshManMode He definitely has issues, but the sentencing seems a bit high',
# ...

# %% [markdown]
# ## Tweet Tokenizer

# %%
from nltk.tokenize import TweetTokenizer
tt = TweetTokenizer()

# %%
tweet_token = []
for sent in df:
    tweet_token.append(tt.tokenize(sent))
    print(tt.tokenize(sent)[0:10])
# Out:
# ['@kunalb11', 'I', '\x92', 'm', 'an', 'alien']
# ['@ID_AA_Carmack', 'Ray', 'tracing', 'on', 'Cyberpunk', 'with', 'HDR', 'is', 'next-level', '.']
# ['@joerogan', '@Spotify', 'Great', 'interview', '!']
# ['@gtera27', 'Doge', 'is', 'underestimated']
# ['@teslacn', 'Congratulations', 'Tesla', 'China', 'for', 'amazing', 'execution', 'last', 'year', '.']
# ['Happy', 'New', 'Year', 'of', 'the', 'Ox', '!', 'https://t.co/9WFKMYu2oj']
# ['Frodo', 'was', 'the', 'underdoge', ',', 'All', 'thought', 'he', 'would', 'fail']
# ['@OwenSparks_', '@flcnhvy', '@anonyx10', 'Haha', 'thanks', ':)']
# ['@flcnhvy', '@anonyx10', 'Indeed', '!', 'Tweets', 'definitely', 'do', 'not', 'represent', 'real-world']
# ['The', 'most', 'entertaining', 'outcome', 'is', 'the', 'most', 'likely']
# ['@GiveDirectly', 'Just', 'sent', 'some']
# ['Just', 'agree', 'to', 'do', 'Clubhouse', 'with', '@kanyewest']
# ['https://t.co/3rWE9uHSTS']
# ['@geoffkeighley', '@UnrealEngine', 'It', '\x92', 's', 'getting', 'real']
# ...

# %%
#tweet_token

# %%
# Now we check sentiment score for sentences(reviews)
from nltk import tokenize
sentences = tokenize.sent_tokenize(' '.join(df))
sentences[5:10]
# Out:
# ['Happy New Year of the Ox!',
#  'https://t.co/9WFKMYu2oj Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all.',
#  'https://t.co/zGxJFDzzrM @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :) @flcnhvy @anonyx10 Indeed!',
#  'Tweets definitely do not represent real-world time allocation.',
# ...

# %%
sent_df = pd.DataFrame(sentences, columns=['sentence'])
sent_df
# Out:
#                                               sentence
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...
# 1                                   Have you tried it?
# 2                  @joerogan @Spotify Great interview!
# 3    @gtera27 Doge is underestimated @teslacn Congr...
# 4                   Now on to the next for even more!!
# ..                                                 ...
# 919  @kenyanwalstreet Not actually a payout, just a...
# 920  It may never pay out, as the stock cant b
#  ht...
# 921                                    Details Aug 28.
# 922  AI symbiosis while u wait @vistacruiser7 @flcn...
# 923  @TeslaGong @PPathole Samwise Gamgee @PPathole ...
#
# [924 rows x 1 columns]

# %% [markdown]
# ## Positive and Negative words

# %%
PositiveWORDS = pd.read_csv("D:\\DATA SCIENCE\\DATA SCIENCE ASSIGNMENTS\\Assignments\\Text Mining (NLP)\\positive-words.txt",error_bad_lines=False,encoding='latin-1')
PositiveWORDS
# Out:
# b'Skipping line 10: expected 1 fields, saw 2\nSkipping line 14: expected 1 fields, saw 5\nSkipping line 15: expected 1 fields, saw 3\nSkipping line 16: expected 1 fields, saw 2\nSkipping line 18: expected 1 fields, saw 3\nSkipping line 19: expected 1 fields, saw 3\nSkipping line 27: expected 1 fields, saw 3\nSkipping line 28: expected 1 fields, saw 2\n'
#      ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 0                                                    ;
# 1                           ; Opinion Lexicon: Positive
# 2                                                     ;
# 3     ; This file contains a list of POSITIVE opinio...
# 4                                                     ;
# ...                                                 ...
# 2026                                           youthful
# 2027                                               zeal
# 2028                                             zenith
# ...

# %%
PositiveWORDS[25:]
# Out:
#      ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 25                                                   a+
# 26                                               abound
# 27                                              abounds
# 28                                            abundance
# 29                                             abundant
# ...                                                 ...
# 2026                                           youthful
# 2027                                               zeal
# 2028                                             zenith
# 2029                                               zest
# 2030                                              zippy
#
# [2006 rows x 1 columns]

# %%
PW = PositiveWORDS[25:]
PW
# Out:
#      ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 25                                                   a+
# 26                                               abound
# 27                                              abounds
# 28                                            abundance
# 29                                             abundant
# ...                                                 ...
# 2026                                           youthful
# 2027                                               zeal
# 2028                                             zenith
# 2029                                               zest
# 2030                                              zippy
#
# [2006 rows x 1 columns]

# %%
PW = PW.rename(columns=({";;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;":"Positive Words"})).reset_index(drop=True)
PW
# Out:
#      Positive Words
# 0                a+
# 1            abound
# 2           abounds
# 3         abundance
# 4          abundant
# ...             ...
# 2001       youthful
# 2002           zeal
# 2003         zenith
# 2004           zest
# 2005          zippy
#
# [2006 rows x 1 columns]

# %%
NegativeWORDS = pd.read_csv("D:\\DATA SCIENCE\\DATA SCIENCE ASSIGNMENTS\\Assignments\\Text Mining (NLP)\\negative-words.txt",error_bad_lines=False,encoding='latin-1')
NegativeWORDS
# Out:
# b'Skipping line 10: expected 1 fields, saw 2\nSkipping line 14: expected 1 fields, saw 5\nSkipping line 15: expected 1 fields, saw 3\nSkipping line 16: expected 1 fields, saw 2\nSkipping line 18: expected 1 fields, saw 3\nSkipping line 19: expected 1 fields, saw 3\nSkipping line 27: expected 1 fields, saw 3\nSkipping line 28: expected 1 fields, saw 2\n'
#      ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 0                                                    ;
# 1                           ; Opinion Lexicon: Negative
# 2                                                     ;
# 3     ; This file contains a list of NEGATIVE opinio...
# 4                                                     ;
# ...                                                 ...
# 4803                                               zaps
# 4804                                             zealot
# 4805                                            zealous
# ...

# %%
NegativeWORDS[25:]
# Out:
#      ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 25                                              2-faced
# 26                                              2-faces
# 27                                             abnormal
# 28                                              abolish
# 29                                           abominable
# ...                                                 ...
# 4803                                               zaps
# 4804                                             zealot
# 4805                                            zealous
# 4806                                          zealously
# 4807                                             zombie
#
# [4783 rows x 1 columns]

# %%
NW = NegativeWORDS[25:]
NW
# Out:
#      ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 25                                              2-faced
# 26                                              2-faces
# 27                                             abnormal
# 28                                              abolish
# 29                                           abominable
# ...                                                 ...
# 4803                                               zaps
# 4804                                             zealot
# 4805                                            zealous
# 4806                                          zealously
# 4807                                             zombie
#
# [4783 rows x 1 columns]

# %%
NW = NW.rename(columns=({";;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;":"Negative Words"})).reset_index(drop=True)
NW
# Out:
#      Negative Words
# 0           2-faced
# 1           2-faces
# 2          abnormal
# 3           abolish
# 4        abominable
# ...             ...
# 4778           zaps
# 4779         zealot
# 4780        zealous
# 4781      zealously
# 4782         zombie
#
# [4783 rows x 1 columns]

# %% [markdown]
# ## Affin laxicon

# %%
#! pip install afinn

# %%
# initialize afinn sentiment analyzer
from afinn import Afinn
af = Afinn()

# %%
# compute sentiment scores (polarity) 
#sentiment_scores = [af.score(PW)]

# %%
#sentiment analysis
afinn = pd.read_csv("D:/jupyter notebook workspace/Text Mining NLP-1and2/Afinn.csv", sep=',', encoding='latin-1')
afinn
# Out:
#            word  value
# 0       abandon     -2
# 1     abandoned     -2
# 2      abandons     -2
# 3      abducted     -2
# 4     abduction     -2
# ...         ...    ...
# 2472      yucky     -2
# 2473      yummy      3
# 2474     zealot     -2
# 2475    zealots     -2
# 2476    zealous      2
#
# [2477 rows x 2 columns]

# %%
afinn.shape
# Out:
# (2477, 2)

# %%
affinity_scores = afinn.set_index('word')['value'].to_dict()
affinity_scores
# Out:
# {'abandon': -2,
#  'abandoned': -2,
#  'abandons': -2,
#  'abducted': -2,
#  'abduction': -2,
#  'abductions': -2,
#  'abhor': -3,
#  'abhorred': -3,
#  'abhorrent': -3,
#  'abhors': -3,
#  'abilities': 2,
#  'ability': 2,
#  'aboard': 1,
#  'absentee': -1,
#  'absentees': -1,
#  'absolve': 2,
#  'absolved': 2,
#  'absolves': 2,
#  'absolving': 2,
#  'absorbed': 1,
#  'abuse': -3,
#  'abused': -3,
#  'abuses': -3,
#  'abusive': -3,
#  'accept': 1,
#  'accepted': 1,
#  'accepting': 1,
#  'accepts': 1,
#  'accident': -2,
#  'accidental': -2,
#  'accidentally': -2,
#  'accidents': -2,
#  'accomplish': 2,
#  'accomplished': 2,
#  'accomplishes': 2,
#  'accusation': -2,
#  'accusations': -2,
#  'accuse': -2,
#  'accused': -2,
#  'accuses': -2,
#  'accusing': -2,
#  'ache': -2,
#  'achievable': 1,
#  'aching': -2,
#  'acquit': 2,
#  'acquits': 2,
#  'acquitted': 2,
#  'acquitting': 2,
#  'acrimonious': -3,
#  'active': 1,
#  'adequate': 1,
#  'admire': 3,
#  'admired': 3,
#  'admires': 3,
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
#custom function: score each word in a sentence in lemmatised form but calculate score for whole original sentences
sentiment_laxicon = affinity_scores

# %%
sentiment_laxicon
# Out:
# {'abandon': -2,
#  'abandoned': -2,
#  'abandons': -2,
#  'abducted': -2,
#  'abduction': -2,
#  'abductions': -2,
#  'abhor': -3,
#  'abhorred': -3,
#  'abhorrent': -3,
#  'abhors': -3,
#  'abilities': 2,
#  'ability': 2,
#  'aboard': 1,
#  'absentee': -1,
#  'absentees': -1,
#  'absolve': 2,
#  'absolved': 2,
#  'absolves': 2,
#  'absolving': 2,
#  'absorbed': 1,
#  'abuse': -3,
#  'abused': -3,
#  'abuses': -3,
#  'abusive': -3,
#  'accept': 1,
#  'accepted': 1,
#  'accepting': 1,
#  'accepts': 1,
#  'accident': -2,
#  'accidental': -2,
#  'accidentally': -2,
#  'accidents': -2,
#  'accomplish': 2,
#  'accomplished': 2,
#  'accomplishes': 2,
#  'accusation': -2,
#  'accusations': -2,
#  'accuse': -2,
#  'accused': -2,
#  'accuses': -2,
#  'accusing': -2,
#  'ache': -2,
#  'achievable': 1,
#  'aching': -2,
#  'acquit': 2,
#  'acquits': 2,
#  'acquitted': 2,
#  'acquitting': 2,
#  'acrimonious': -3,
#  'active': 1,
#  'adequate': 1,
#  'admire': 3,
#  'admired': 3,
#  'admires': 3,
# ...

# %%
def calculate_sentiment (text: str=None):
    sent_score=0
    if text:
        sentence=nlp(text)
        for word in sentence:
            sent_score += sentiment_laxicon.get(word.lemma_, 0)
    return sent_score

# %%
# calculate sentiment value and add to sent_df
sent_df['sentiment_value'] = sent_df['sentence'].apply(calculate_sentiment)
sent_df
# Out:
#                                               sentence  sentiment_value
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                   Have you tried it?                0
# 2                  @joerogan @Spotify Great interview!                3
# 3    @gtera27 Doge is underestimated @teslacn Congr...                3
# 4                   Now on to the next for even more!!                0
# ..                                                 ...              ...
# 919  @kenyanwalstreet Not actually a payout, just a...                0
# 920  It may never pay out, as the stock cant b
#  ht...               -4
# 921                                    Details Aug 28.                0
# 922  AI symbiosis while u wait @vistacruiser7 @flcn...               -2
# 923  @TeslaGong @PPathole Samwise Gamgee @PPathole ...                0
#
# [924 rows x 2 columns]

# %%
# how many words are in the sentence
sent_df['word_count'] = sent_df['sentence'].str.split().apply(len)
sent_df['word_count']
# Out:
# 0      13
# 1       4
# 2       4
# 3      13
# 4       8
#        ..
# 919    11
# 920    31
# 921     3
# 922    47
# 923    15
# Name: word_count, Length: 924, dtype: int64

# %%
sent_df
# Out:
#                                               sentence  sentiment_value  \
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                   Have you tried it?                0
# 2                  @joerogan @Spotify Great interview!                3
# 3    @gtera27 Doge is underestimated @teslacn Congr...                3
# 4                   Now on to the next for even more!!                0
# ..                                                 ...              ...
# 919  @kenyanwalstreet Not actually a payout, just a...                0
# 920  It may never pay out, as the stock cant b
#  ht...               -4
# 921                                    Details Aug 28.                0
# 922  AI symbiosis while u wait @vistacruiser7 @flcn...               -2
# 923  @TeslaGong @PPathole Samwise Gamgee @PPathole ...                0
#
#      word_count
# 0            13
# 1             4
# 2             4
# 3            13
# ...

# %%
sent_df.sort_values(by='sentiment_value').tail(10)
# Out:
#                                               sentence  sentiment_value  \
# 183  Theres some great AI out ther
#  https://t.co/v...               10
# 224  @PPathole @karpathy For a second there, I thou...               11
# 817  Might be able to
#  https://t.co/FB7e5nOq2E @Pri...               11
# 184  Also, w
#  https://t.co/IYdKttVsqk @cleantechnic...               12
# 645  Its
#  https://t.co/IxhyT6NuiC @Teslarati Tesla...               13
# 81   @teslaownersSV This is a good one @MrBeastYT I...               13
# 585  The open areas
#  https://t.co/rabjKrtQlw @Sav...               14
# 719  We just havent observed the
#  https://t.co/mez...               15
# 36   @ajtourville @Erdayastronaut @SpaceX Yes, but ...               15
# 105  @Erdayastronaut @SpaceX Was also thinking that...               16
#
#      word_count
# 183          48
# 224          69
# 817          72
# 184          98
# 645          65
# 81           38
# 585         138
# 719          72
# ...

# %% [markdown]
# ## Description

# %%
# sentiment score of the whole review
sent_df['sentiment_value'].describe()
# Out:
# count    924.000000
# mean       1.352814
# std        2.671421
# min       -8.000000
# 25%        0.000000
# 50%        0.000000
# 75%        3.000000
# max       16.000000
# Name: sentiment_value, dtype: float64

# %% [markdown]
# #### we see that above the minimum sentiment value is -8 and maximum sentiment value is 16
# #### AND mean towards 1.35( i. e. overall sentiment score is positive)

# %%
# Sentiment score of the whole review <=0
sent_df[sent_df['sentiment_value']<=0]
# Out:
#                                               sentence  sentiment_value  \
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                   Have you tried it?                0
# 4                   Now on to the next for even more!!                0
# 6    https://t.co/9WFKMYu2oj Frodo was the underdog...               -2
# 8    Tweets definitely do not represent real-world ...                0
# ..                                                 ...              ...
# 919  @kenyanwalstreet Not actually a payout, just a...                0
# 920  It may never pay out, as the stock cant b
#  ht...               -4
# 921                                    Details Aug 28.                0
# 922  AI symbiosis while u wait @vistacruiser7 @flcn...               -2
# 923  @TeslaGong @PPathole Samwise Gamgee @PPathole ...                0
#
#      word_count
# 0            13
# 1             4
# 4             8
# 6            14
# ...

# %%
# Sentiment score of the whole review >=10
sent_df[sent_df['sentiment_value']>=10]
# Out:
#                                               sentence  sentiment_value  \
# 36   @ajtourville @Erdayastronaut @SpaceX Yes, but ...               15
# 81   @teslaownersSV This is a good one @MrBeastYT I...               13
# 105  @Erdayastronaut @SpaceX Was also thinking that...               16
# 159  @harsimranbansal @heydave7 It will most likely...               10
# 183  Theres some great AI out ther
#  https://t.co/v...               10
# 184  Also, w
#  https://t.co/IYdKttVsqk @cleantechnic...               12
# 224  @PPathole @karpathy For a second there, I thou...               11
# 585  The open areas
#  https://t.co/rabjKrtQlw @Sav...               14
# 645  Its
#  https://t.co/IxhyT6NuiC @Teslarati Tesla...               13
# 719  We just havent observed the
#  https://t.co/mez...               15
# 817  Might be able to
#  https://t.co/FB7e5nOq2E @Pri...               11
# 855  Impressive Tianwen-1 Mars rover mission launch...               10
#
#      word_count
# ...

# %%
sent_df['index']=range(0,len(sent_df))

# %%
sent_df=sent_df[['index']+['sentence']+['word_count']+['sentiment_value']]
sent_df.reset_index(drop=True)
sent_df
# Out:
#      index                                           sentence  word_count  \
# 0        0  @kunalb11 Im an alien @ID_AA_Carmack Ray trac...          13
# 1        1                                 Have you tried it?           4
# 2        2                @joerogan @Spotify Great interview!           4
# 3        3  @gtera27 Doge is underestimated @teslacn Congr...          13
# 4        4                 Now on to the next for even more!!           8
# ..     ...                                                ...         ...
# 919    919  @kenyanwalstreet Not actually a payout, just a...          11
# 920    920  It may never pay out, as the stock cant b
#  ht...          31
# 921    921                                    Details Aug 28.           3
# 922    922  AI symbiosis while u wait @vistacruiser7 @flcn...          47
# 923    923  @TeslaGong @PPathole Samwise Gamgee @PPathole ...          15
#
#      sentiment_value
# 0                  0
# 1                  0
# ...

# %% [markdown]
# ### Assign labels

# %%
sentiment = []
for i in range(len(sent_df)):
  c = sent_df.loc[i]['sentiment_value']
  if c>0:
    sentiment.append("positive")
  elif c<0:
    sentiment.append("Negative")
  else:
    sentiment.append("Neutral")
sent_df['Sentiment']=sentiment
sent_df
# Out:
# <ipython-input-88-1de013f99034>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_df['Sentiment']=sentiment
#      index                                           sentence  word_count  \
# 0        0  @kunalb11 Im an alien @ID_AA_Carmack Ray trac...          13
# 1        1                                 Have you tried it?           4
# 2        2                @joerogan @Spotify Great interview!           4
# 3        3  @gtera27 Doge is underestimated @teslacn Congr...          13
# 4        4                 Now on to the next for even more!!           8
# ..     ...                                                ...         ...
# 919    919  @kenyanwalstreet Not actually a payout, just a...          11
# ...

# %% [markdown]
# # Visualization

# %%
sent_df['Sentiment'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Positive reviews are maximum followed by Neutral and followed by Negative reviews

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(sent_df['sentiment_value'])

# %% [markdown]
# #### from displot maximum reviews in between 0 to 1

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x='index', y='sentiment_value', data=sent_df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='sentiment_value'>

# %% [markdown]
# #### from line plot we say that most sebtiment values in between 0 to 5

# %%
sent_df.plot.scatter(x='word_count', y='sentiment_value', figsize=(10,8), title='SENTENCE SENTIMENT VALUE TO SENTENCE WORD COUNT')
# Out:
# <AxesSubplot:title={'center':'SENTENCE SENTIMENT VALUE TO SENTENCE WORD COUNT'}, xlabel='word_count', ylabel='sentiment_value'>

# %% [markdown]
# ### from scatter plot we say that most sentiment values of sentence in between 0 to 5 with word count of sentence in between 0 to 50
